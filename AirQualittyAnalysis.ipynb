# %% [markdown]
# # Loading Your Data

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\emych\Desktop\Air Quality Analysis in Houston\ad_viz_plotval_data.csv')

# %%
df
# Out:
#             Date Source    Site ID  POC  Daily Mean PM2.5 Concentration  \
# 0     01/06/2023    AQS  480391012    5                             3.2
# 1     01/12/2023    AQS  480391012    5                             4.7
# 2     01/18/2023    AQS  480391012    5                             9.1
# 3     01/24/2023    AQS  480391012    5                             6.0
# 4     01/30/2023    AQS  480391012    5                            10.6
# ...          ...    ...        ...  ...                             ...
# 4959  12/27/2023    AQS  483390078    1                             5.0
# 4960  12/28/2023    AQS  483390078    1                             5.2
# 4961  12/29/2023    AQS  483390078    1                             5.3
# 4962  12/30/2023    AQS  483390078    1                            10.6
# 4963  12/31/2023    AQS  483390078    1                            34.4
#
#          Units  Daily AQI Value          Local Site Name  Daily Obs Count  \
# ...

# %% [markdown]
# # Clean and Prepare Data
# ## Handle missing values (if any)
# ## Convert date column to datetime

# %%
df.isnull().sum()
# Out:
# Date                              0
# Source                            0
# Site ID                           0
# POC                               0
# Daily Mean PM2.5 Concentration    0
# Units                             0
# Daily AQI Value                   0
# Local Site Name                   0
# Daily Obs Count                   0
# Percent Complete                  0
# AQS Parameter Code                0
# AQS Parameter Description         0
# Method Code                       0
# Method Description                0
# CBSA Code                         0
# CBSA Name                         0
# State FIPS Code                   0
# State                             0
# County FIPS Code                  0
# County                            0
# Site Latitude                     0
# Site Longitude                    0
# dtype: int64

# %%
df.dtypes
# Out:
# Date                               object
# Source                             object
# Site ID                             int64
# POC                                 int64
# Daily Mean PM2.5 Concentration    float64
# Units                              object
# Daily AQI Value                     int64
# Local Site Name                    object
# Daily Obs Count                     int64
# Percent Complete                  float64
# AQS Parameter Code                  int64
# AQS Parameter Description          object
# Method Code                         int64
# Method Description                 object
# CBSA Code                           int64
# CBSA Name                          object
# State FIPS Code                     int64
# State                              object
# County FIPS Code                    int64
# County                             object
# Site Latitude                     float64
# Site Longitude                    float64
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#            Date Source    Site ID  POC  Daily Mean PM2.5 Concentration  \
# 0    2023-01-06    AQS  480391012    5                             3.2
# 1    2023-01-12    AQS  480391012    5                             4.7
# 2    2023-01-18    AQS  480391012    5                             9.1
# 3    2023-01-24    AQS  480391012    5                             6.0
# 4    2023-01-30    AQS  480391012    5                            10.6
# ...         ...    ...        ...  ...                             ...
# 4959 2023-12-27    AQS  483390078    1                             5.0
# 4960 2023-12-28    AQS  483390078    1                             5.2
# 4961 2023-12-29    AQS  483390078    1                             5.3
# 4962 2023-12-30    AQS  483390078    1                            10.6
# 4963 2023-12-31    AQS  483390078    1                            34.4
#
#          Units  Daily AQI Value          Local Site Name  Daily Obs Count  \
# ...

# %% [markdown]
# # Explore the Data
# ## Add columns for month and day of the week
# ## Calculate basic stats

# %%
df['Month'] = df['Date'].dt.month
df['DayOfWeek'] = df['Date'].dt.day_name()

df['Daily Mean PM2.5 Concentration'].describe()
# Out:
# count    4964.000000
# mean       10.676531
# std         5.056589
# min        -0.300000
# 25%         7.100000
# 50%         9.800000
# 75%        13.300000
# max        43.800000
# Name: Daily Mean PM2.5 Concentration, dtype: float64

# %% [markdown]
# # Visualize Trends
# ## Plot daily PM2.5 levels over the year

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(df['Date'], df['Daily Mean PM2.5 Concentration'], marker='o', linestyle='-', markersize=3)
plt.title('Daily PM2.5 Levels in Houston (2023)')
plt.xlabel('Date')
plt.ylabel('PM2.5 Concentration (µg/m³)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plot average PM2.5 by month

# %%
import os
import matplotlib.pyplot as plt

# Create the directory if it doesn't exist
os.makedirs("plots", exist_ok=True)

# Then plot and save your figure
plt.plot([1, 2, 3], [4, 5, 6])  # replace with your actual plot
plt.title("Monthly PM2.5 Trend")
plt.xlabel("Month")
plt.ylabel("Average PM2.5 (µg/m³)")
plt.savefig("plots/monthly_pm25_trend.png")
plt.show()

# %% [markdown]
# ## Plot PM2.5 by day of the week

# %%
weekday_avg = df.groupby('DayOfWeek')['Daily Mean PM2.5 Concentration'].mean()
# Sort days in order
order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
weekday_avg = weekday_avg.reindex(order)

plt.figure(figsize=(8,5))
weekday_avg.plot(kind='bar', color='coral')
plt.title('Average PM2.5 by Day of Week (2023)')
plt.xlabel('Day of Week')
plt.ylabel('Average PM2.5 (µg/m³)')
plt.savefig("plots/weekly_pm25_trend.png")
plt.show()

# %% [markdown]
# Air Quality Analysis Report: PM2.5 in Houston (2023)
# By Chisom Mbah
#
# 1. Project Overview
# This project analyzes daily PM2.5 air pollution levels in Houston, Texas, during the year 2023. PM2.5 (particulate matter smaller than 2.5 micrometers) is an important indicator of air quality, impacting human health and the environment.
#
# 2. Data Source
# The data was sourced from the EPA AirData portal, containing daily PM2.5 measurements recorded at monitoring stations across Houston throughout 2023.
#
# 3. Data Preparation
# Loaded the dataset and converted date columns to datetime format.
#
# Cleaned missing values by removing records without PM2.5 data.
#
# Added additional columns for month and day of the week to explore temporal patterns.
#
# 4. Exploratory Data Analysis
# Daily Trends: Visualized daily PM2.5 levels across the year, showing fluctuations and spikes.
#
# Monthly Averages: Identified which months had the highest and lowest average PM2.5 concentrations.
#
# Weekly Patterns: Compared average PM2.5 levels by day of the week to see if weekdays differ from weekends.
#
# 5. Results / Findings
# “The average monthly PM2.5 concentrations in Houston during 2023 varied throughout the year. The highest average levels were observed in July (20.7 µg/m³), indicating a period of increased air pollution. The lowest averages occurred in February (10.8 µg/m³). Daily PM2.5 data revealed several spikes, with the most significant peak occurring around mid-July. This suggests that air quality tends to worsen during the summer months.”
#
# Discussion
# “The elevated PM2.5 levels in July could be attributed to higher temperatures that increase the formation of secondary pollutants and possibly increased industrial activity or wildfires in the region. Such elevated particulate matter poses health risks, particularly to children, the elderly, and individuals with respiratory conditions. Understanding these patterns can guide local authorities in implementing timely air quality advisories and pollution control measures.”.
#
# Conclusion:
# “In summary, Houston experienced higher PM2.5 pollution in summer 2023, highlighting seasonal air quality challenges. Continued monitoring and mitigation efforts are essential to protect public health.”
